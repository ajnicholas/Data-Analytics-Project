# %% [markdown]
# <a href="https://colab.research.google.com/github/ajnicholas/Data-Analytics-Project/blob/main/DA_Yellow_Assignment2_408534_Nicholas_Aiwonegbe_Ajnicholas2000_gmail_com.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
my_file = files.upload()
# Out:
#      <input type="file" id="files-cfd5d350-be4c-4b9f-bad5-766618c9d6d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfd5d350-be4c-4b9f-bad5-766618c9d6d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['Survived'].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
Passenger_distribution_class = df['Pclass'].value_counts().sort_index()
Passenger_distribution_class.plot(kind='bar', color='Pink', edgecolor='black')
plt.title('Passenger Class Distribution'), plt.xlabel('Passenger Class'), plt.ylabel('Number of Passengers'), plt.xticks(rotation=0)
plt.show()

# %%
Passenger_age = df['Age']
plt.hist(Passenger_age, bins=20, color='purple', edgecolor='black'), plt.title('Age Distribution of Passengers'), plt.xlabel('Age'), plt.ylabel('Number of Passengers')
plt.show()

# %%
survival_count = df['Survived'].value_counts()
total_passengers = len(df)
survival_rate = survival_count / total_passengers
labels = ['Did Not Survive', 'Survived']
colors = ['skyblue', 'Red']
plt.pie(survival_rate, labels=labels, colors=colors, autopct='%1.1f%%'), plt.axis('equal'), plt.title('Survival Rate of Passengers')
plt.show()

# %%
gender_counts = df['Sex'].value_counts()
gender_labels = gender_counts.index
count = gender_counts.values
plt.bar(gender_labels, count, color=['black', 'yellow']), plt.title('Passenger Count by Gender'), plt.xlabel('Gender'), plt.ylabel('Number of Passengers'), plt.xticks(rotation=0)
plt.show()

# %%
gender_survival = df.groupby(['Sex', 'Survived'])['PassengerId'].count().unstack()
stackedchart = gender_survival.plot(kind='bar', stacked=True, colormap='Set2')
plt.title('Survival Rate by Gender'), plt.xlabel('Gender'), plt.ylabel('Number of Passengers'), plt.xticks(rotation=0), plt.legend(['Did not survive', 'Survived'], loc='upper left', title='Survival')
description = "The stacked bar chart seems to illustrate a higher survival rate in woman compared to men"
plt.gcf().text(0.1, 0.005, description, fontsize=9)
plt.show()

# %%
import seaborn as sns
sns.set(style="darkgrid")
sns.countplot(x="Embarked", data=df, palette="Set1")
plt.title('Number of Passengers by Embarkation Location'), plt.xlabel('Embarkation Location'), plt.ylabel('Number of Passengers')
plt.show()
# Out:
# <ipython-input-16-7724bbc5bca0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Embarked", data=df, palette="Set1")

# %%
plt.boxplot(df['Parch'])
plt.xlabel('Family size')
plt.ylabel('Count')
plt.title('Distribution of Family Sizes Among Passengers')
plt.show()

# %%
plt.figure(figsize=(9, 9))
sns.scatterplot(x='Fare', y='Age', data=df, alpha=0.6)
df_filtered = df.dropna(subset=['Age'])
plt.xlabel('Fare'), plt.ylabel('Age'), plt.title('Comparison Between the Fare and Age of passengers')
description = "The passengers who paid higher fares do not tend to be older"
plt.gcf().text(0.1, 0.005, description, fontsize=9)
plt.show()

# %%
from google.colab import files
my_file = files.upload()
# Out:
#      <input type="file" id="files-67635136-57be-4ad4-89ca-ebba551c2902" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67635136-57be-4ad4-89ca-ebba551c2902">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('Corona_NLP.csv')

# %%
df.tail(10)

# %%
df = pd.read_csv('Corona_NLP.csv')
duplicates = df.duplicated(keep='first')
print("Duplicate Rows:", df[duplicates])
df_no_duplicates = df.drop_duplicates(keep='first')
print("\nDataFrame without Duplicates:")
print(df_no_duplicates)

# %%
df = pd.read_csv('Corona_NLP.csv')
location_Frequency = df['Location'].value_counts().sort_values(ascending=False)
print (location_Frequency)
import matplotlib.pyplot as plt
Top_20_locations = df['Location'].value_counts().head(20)
plt.figure(figsize = (9,9)), Top_20_locations.plot(kind='bar'), plt.title('Top 20 Locations by Frequency'), plt.xlabel('Location'), plt.ylabel('Frequency'), plt.xticks(rotation=80)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
colors = sns.color_palette("Set2")
sns.set(style="darkgrid")
plt.figure(figsize=(9,9)), sns.countplot(data=df, x="Sentiment", palette=colors, order=["Extremely Negative", "Negative", "Neutral", "Positive", "Extremely Positive"])
plt.title("Sentiment Distribution"), plt.xlabel("Sentiment"), plt.ylabel("Count"), plt.xticks(rotation=80)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
colors = sns.color_palette("Set2")
sns.set(style="darkgrid")
df['Sentiment'].replace({"Extremely Negative": "Negative", "Positive": "Positive", "Extremely Positive": "Positive"}, inplace=True)
plt.figure(figsize=(9,9)), sns.countplot(data=df, x="Sentiment", palette=colors, order=["Negative", "Positive"])
plt.title("Sentiment Distribution"), plt.xlabel("Sentiment"), plt.ylabel("Count"), plt.xticks(rotation=80)
plt.show()

# %%
import re
import string
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download("stopwords")
nltk.download('wordnet')
stop_words = set(stopwords.words("english"))

# %%
def cleantweets(text):
    if isinstance(text, str):
        text = text.lower()
        text_no_links = re.sub(r'http\S+', '', text)
        text_no_at = re.sub(r'@\w+', '', text_no_links)
        text_no_hashtags = re.sub(r'#\w+', '', text_no_at)
        cleaned_text = re.sub(r'[\n\r]', ' ', text_no_hashtags)
        return cleaned_text
    else:
        return text
df["cleaned original tweets"] = df['OriginalTweet'].apply(cleantweets)
df.tail(10)

# %%
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
tokenizer = TweetTokenizer()
nltk_stopwords = set(stopwords.words('english'))
def cleaned_tokenize_text(text):
  if isinstance(text, str):
    tokenized_text = tokenizer.tokenize(text)
    cleaned_tokens = [token.lower() for token in tokenized_text if token.lower() not in nltk_stopwords and not re.match(r'[^\w\s]', token)]
    return cleaned_tokens
  else:
    return []
  import string
df["Clean_TokenizedTweets"] = df['cleaned original tweets'].apply(cleaned_tokenize_text)
df.tail(10)

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
def stem_tweets(text):
    if isinstance(text, str):
        tokens = text.split()
        stemmed_tokens = [stemmer.stem(token) for token in tokens]
        stemmed_text = ' '.join(stemmed_tokens)
        return stemmed_text
    else:
        return []
df["stemmedtweets"] = df['cleaned original tweets'].apply(stem_tweets)
df.head(5)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
df = pd.read_csv('Corona_NLP.csv')
df['OriginalTweet'].fillna('', inplace=True)
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['OriginalTweet'])
print(tfidf_matrix)

# %%
from sklearn.model_selection import train_test_split
X = df['OriginalTweet']
y = df['Sentiment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)
print("Training set size:", len(X_train))
print("Test set size:", len(X_test))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
df['OriginalTweet'].fillna('', inplace=True)
df['Sentiment'].fillna('', inplace=True)
X = df['OriginalTweet']
y = df['Sentiment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)
tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)
logistic_regression_model = LogisticRegression(max_iter=1000)
logistic_regression_model.fit(X_train_tfidf, y_train)
y_pred = logistic_regression_model.predict(X_test_tfidf)
accuracy = accuracy_score(y_test, y_pred)
classification_report_str = classification_report(y_test, y_pred)
print(f"Accuracy: {accuracy}") #Accuracy is 57.26%
print(f"Classification Report:\n{classification_report_str}")

# %%
from google.colab import files
my_file = files.upload()

# %%
import pandas as pd
import numpy as np
from scipy import stats
df = pd.read_csv('q3_data.csv')
mean_x1 = df['x1'].mean()
mean_x2 = df['x2'].mean()
mode_x1 = stats.mode(df['x1']).mode
mode_x2 = stats.mode(df['x2']).mode
median_x1 = df['x1'].median()
median_x2 = df['x2'].median()
Q1_x1 = df['x1'].quantile(0.25)
Q3_x1 = df['x1'].quantile(0.75)
IQR_x1 = Q3_x1 - Q1_x1
Q1_x2 = df['x2'].quantile(0.25)
Q3_x2 = df['x2'].quantile(0.75)
IQR_x2 = Q3_x2 - Q1_x2
print(f"Mean x1: {mean_x1}")
print(f"Mean x2: {mean_x2}")
print(f"Mode x1: {mode_x1}")
print(f"Mode x2: {mode_x2}")
print(f"Median x1: {median_x1}")
print(f"Median x2: {median_x2}")
print(f"IQR x1: {IQR_x1}")
print(f"IQR x2: {IQR_x2}")

# %%
correlation_coefficient = df['x1'].corr(df['x2'])
print(f"Correlation coefficient between x1 and x2: {correlation_coefficient}")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.regplot(x='x1', y='x2', data=df)
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('q3_data_regression_plot')
description = "comment: The correlation coefficient between x1 and x2 being -0.8318445482811824 suggests a strong negative correlation, The linear regression line is not a well represented model as X2 seems to have a strong negative correlation while X1 has no correlation at all, the scatter plot indicates a structural break due to the difference in correlation between X1 and X2"
plt.gcf().text(0.1, 0.005, description, fontsize=9)
plt.show()
